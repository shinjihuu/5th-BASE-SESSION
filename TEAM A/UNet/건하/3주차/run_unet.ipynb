# %%
# %load_ext tensorboard

# %%
tensorboard --logdir='./drive/MyDrive/002-pytorch-unet/log'

# %%
# !python3 './drive/MyDrive/002-pytorch-unet/train.py' \
--lr 1e-2 --batch_size 6 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/002-pytorch-unet/datasets' \
--ckpt_dir '/content/drive/MyDrive/002-pytorch-unet/checkpoint' \
--log_dir '/content/drive/MyDrive/002-pytorch-unet/log' \
--result_dir '/content/drive/MyDrive/002-pytorch-unet/results' \
--mode 'train' \
--train_continue 'off'

# %%
# !python3 './drive/MyDrive/002-pytorch-unet/train.py' \
--lr 1e-2 --batch_size 2 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/002-pytorch-unet/datasets' \
--ckpt_dir '/content/drive/MyDrive/002-pytorch-unet/checkpoint' \
--log_dir '/content/drive/MyDrive/002-pytorch-unet/log' \
--result_dir '/content/drive/MyDrive/002-pytorch-unet/results' \
--mode 'test' \
--train_continue 'off'
# Out:
# TEST: BATCH 0001 / 0012 | LOSS 0.1958
# TEST: BATCH 0002 / 0012 | LOSS 0.1939
# TEST: BATCH 0003 / 0012 | LOSS 0.1900
# TEST: BATCH 0004 / 0012 | LOSS 0.1897
# TEST: BATCH 0005 / 0012 | LOSS 0.1930
# TEST: BATCH 0006 / 0012 | LOSS 0.1983
# TEST: BATCH 0007 / 0012 | LOSS 0.2044
# TEST: BATCH 0008 / 0012 | LOSS 0.2027
# TEST: BATCH 0009 / 0012 | LOSS 0.2015
# TEST: BATCH 0010 / 0012 | LOSS 0.2014
# TEST: BATCH 0011 / 0012 | LOSS 0.2007
# TEST: BATCH 0012 / 0012 | LOSS 0.2004
# AVERAGE TEST: BATCH 0012 / 0012 | LOSS 0.2004
